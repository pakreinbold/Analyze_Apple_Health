# %% [markdown]
# # Analyze Downloaded Apple Health Data

# %%
from fitness_processing import FitnessProcessor

fp = FitnessProcessor()
# Out:
# Cache last updated on 2021-11-19
# Processing .xml files ...
# Getting heart rate data
# Getting run data
# Saving csvs to cache

# %%
fp.is_github = False # Remove this line for interactive plot
fp.plot_run(y_data='Pace', sz_data='Distance', clr_data='Avg HR')

# %%
fig = fp.plot_run_hr('2021-11-18')
# Out:
# <class 'plotly.graph_objs._figure.Figure'>

# %%
fp.runs.tail(10)
# Out:
#            Date  Distance   Duration       Pace     Speed      Avg HR  Max HR  \
# 127  2021-09-13  3.010840  39.993983  13.283331  4.516939  161.540948   194.0
# 128  2021-09-16  1.024307  10.336209  10.090930  5.945934  167.900000   189.0
# 129  2021-09-20  2.646080  35.598355  13.453242  4.459892  158.256790   189.0
# 130  2021-09-21  1.797306  26.030649  14.483152  4.142745  135.773649   180.0
# 131  2021-10-01  1.882104  24.827500  13.191351  4.548435  163.655172   189.0
# 132  2021-10-04  2.032343  25.626818  12.609493  4.758320  164.072165   187.0
# 133  2021-10-06  1.541795  18.764837  12.170771  4.929844  159.140777   188.0
# 134  2021-10-09  2.079360  25.182426  12.110664  4.954311  160.282828   189.0
# 135  2021-10-22  1.518482  20.050000  13.203976  4.544086         NaN     NaN
# 136  2021-11-18  3.116506  45.727328  14.672626  4.089248  158.577697   188.0
#
#          Energy  Temperature  Humidity Indoor   Elevation     Start       End
# 127  433.078000         87.8      44.0      0         NaN  16:29:35  17:09:35
# 128  144.916038         78.8      70.0      0         NaN  16:34:36  16:44:56
# 129  374.998250         78.8      59.0      0  445.770000  17:53:03  18:28:39
# 130  242.894633         73.4      96.0      0   44.238333  16:58:32  17:24:34
# 131  269.191085         78.8      50.0      0         NaN  17:01:33  17:26:22
# 132  284.691434         78.8      63.0      0         NaN  15:56:33  16:22:10
# 133  210.028380         80.6      66.0      0         NaN  16:19:12  16:37:58
# 134  287.080602         71.6      75.0      0         NaN  15:20:02  15:45:13
# 135    0.000000          NaN       NaN      0         NaN  16:53:56  17:13:59
# 136  459.302000          NaN       NaN      0         NaN  16:43:07  17:28:51

# %%
fp.heart_rates.tail(10)
# Out:
#                            Time  Value       Unit
# 40093 2021-11-18 17:31:24-05:00  152.0  count/min
# 40094 2021-11-18 17:31:29-05:00  152.0  count/min
# 40095 2021-11-18 17:31:34-05:00  151.0  count/min
# 40096 2021-11-18 17:31:36-05:00  151.0  count/min
# 40097 2021-11-18 17:31:44-05:00  149.0  count/min
# 40098 2021-11-18 17:31:47-05:00  150.0  count/min
# 40099 2021-11-18 17:31:53-05:00  149.0  count/min
# 40100 2021-11-18 17:31:56-05:00  148.0  count/min
# 40101 2021-11-18 17:32:00-05:00  150.0  count/min
# 40102 2021-11-18 17:32:06-05:00  153.0  count/min

# %%
fp.update_cache()
# Out:
# Processing .xml files ...
# Getting heart rate data
# Getting run data
# Saving csvs to cache

# %% [markdown]
# # Machine learning ideas
#
# ## Run performance predictor
#
# Build neural net that can predict workout metrics given prior information
#
# ### Inputs:
# A) Information about the workout you'd like to predict
# - Date
# - Distance
# - Temperature
# - Humidity
# - Indoor
# - Time of day (start)
#
# B) Information about previous workouts (5?)
# - Date (or how far in the past it was)
# - All inputs & outpus from those workouts
#
# ### Outputs:
# - Duration/pace/speed
# - Average HR
# - Max HR
# - Energy
#
# ## Heart rate shape learner
#
# - Learn the heart rate curve based on all heart rate measurements during a workout.
#     - make sure to filter out the "steps"
# - Make an algorithm that can detect starts & stops of walking.
# - Sample this curve at regular intervals.
# - Using only heart rate statistics (min, max, avg, etc.) and walking start-stop locations, predict the heart rate curve.
# - Connect to run performance neural net.
